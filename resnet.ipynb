# %% [markdown]
# # Install dependencies

# %%
# !pip install -q nlpaug
# !pip install -q opencv-python
# !pip install -q torch
# !pip install -q cmapy

#many others may be needed to install on other environements

# %%
import numpy, librosa, nlpaug, cv2, pandas, torch, sklearn, tqdm, cmapy

# %%
# Create a directory to save the models generated during the training
from pathlib import Path

Path('/kaggle/working/models').mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Training and testing commands

# %%
# S'ha de correr amb la GPU T4 x2 !!!!

# Training
# !python /kaggle/input/resnet-main/RespireNet-kaggle/train.py --data_dir /kaggle/input/resnetds/audio_text_data/ --folds_file /kaggle/input/resnet-main/RespireNet-kaggle/data/patient_list_foldwise.txt --model_path /kaggle/working/models/ --lr 1e-3 --batch_size 64 --num_worker 4 --start_epochs 0 --epochs 200 --test_fold 4

# Testing
# !python /kaggle/input/resnet-main/RespireNet-kaggle/eval.py --data_dir /kaggle/input/resnetds/audio_text_data/ --folds_file /kaggle/input/resnet-main/RespireNet-kaggle/data/patient_list_foldwise.txt --batch_size 64 --num_worker 4 --test_fold 4 --checkpoint /kaggle/input/resnet-main/RespireNet-kaggle/models/ckpt_best.pkl
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Train import done successfully
# DEVICE DICT {'Meditron': 0, 'AKGC417L': 1, 'Litt3200': 2, 'LittC2SE': 3}
# Device 0 64
# Device 1 32
# Device 2 11
# Device 3 23
# Getting filenames ...
# Exracting Individual Cycles
# 722it [00:13, 55.23it/s]
# TRAIN DETAILS
# CLASSWISE SAMPLE COUNTS: [2878. 1474.  683.  436.]
# Device to ID {'Meditron': 0, 'AKGC417L': 1, 'Litt3200': 2, 'LittC2SE': 3}
# DEVICE ID 0 size 1288
# DEVICE ID 1 size 3436
# DEVICE ID 2 size 350
# DEVICE ID 3 size 397
# CLASSWISE PROBS [0.52604643 0.26942058 0.12484007 0.07969293]
# LEN AUDIO DATA 5471
# ==> Computing mean and std..
# MEAN tensor([0.5030, 0.1708, 0.4368]) STD tensor([0.2307, 0.1278, 0.0736])
# ...
